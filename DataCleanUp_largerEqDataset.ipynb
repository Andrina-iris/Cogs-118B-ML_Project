# %%
import pandas as pd
import numpy as np

#Upload File
df = pd.read_csv("largerEqDataset.csv", sep=",")

df
# Out:
#       Year  Month  Day      Time      Lat       Lon  Depth  Mag  \
# 0     2022     12    3  22:35:18  38.7748 -122.7645    0.2  0.4
# 1     2022     12    3  22:27:51  34.5200 -118.9598   10.7  1.8
# 2     2022     12    3  22:14:00  62.9029 -150.9087   89.0  1.1
# 3     2022     12    3  22:05:38  33.8388 -116.7710   16.2  1.5
# 4     2022     12    3  21:58:08  65.1832 -145.3003    6.0  1.6
# ...    ...    ...  ...       ...      ...       ...    ...  ...
# 4995  2022     11   17  14:03:42  59.9210 -153.1838  111.2  1.9
# 4996  2022     11   17  14:03:20  33.2170 -116.7482   11.2  0.7
# 4997  2022     11   17  13:59:32  26.9701   55.2311   10.0  5.2
# 4998  2022     11   17  13:54:46  36.5818 -121.1080   10.8  1.0
# 4999  2022     11   17  13:53:00  17.9603  -66.9652   11.7  2.1
#
#                                  Region   Timestamp
# 0            1km WSW of The Geysers, CA  1670106918
# 1              14km NNW of Fillmore, CA  1670106471
# ...

# %%
#Add zero infront of single digit days and months
df['Day'] = (df['Day'].astype(str)).apply(lambda x: x.zfill(2))
df['Month'] = (df['Month'].astype(str)).apply(lambda x: x.zfill(2))

#Combine Year, Month, Day into Date column
#Date Format: YYYY-MM-DD
df['Date'] = df['Year'].astype(str) + '-' + df['Month'].astype(str) + '-' + df['Day'].astype(str)
df.insert(0,'Date', df.pop('Date'))

#Drop columns
df = df.drop(['Year', 'Month','Day','Timestamp'], axis = 1)
df
# Out:
#             Date      Time      Lat       Lon  Depth  Mag  \
# 0     2022-12-03  22:35:18  38.7748 -122.7645    0.2  0.4
# 1     2022-12-03  22:27:51  34.5200 -118.9598   10.7  1.8
# 2     2022-12-03  22:14:00  62.9029 -150.9087   89.0  1.1
# 3     2022-12-03  22:05:38  33.8388 -116.7710   16.2  1.5
# 4     2022-12-03  21:58:08  65.1832 -145.3003    6.0  1.6
# ...          ...       ...      ...       ...    ...  ...
# 4995  2022-11-17  14:03:42  59.9210 -153.1838  111.2  1.9
# 4996  2022-11-17  14:03:20  33.2170 -116.7482   11.2  0.7
# 4997  2022-11-17  13:59:32  26.9701   55.2311   10.0  5.2
# 4998  2022-11-17  13:54:46  36.5818 -121.1080   10.8  1.0
# 4999  2022-11-17  13:53:00  17.9603  -66.9652   11.7  2.1
#
#                                  Region
# 0            1km WSW of The Geysers, CA
# 1              14km NNW of Fillmore, CA
# 2        45 km N of Petersville, Alaska
# 3                  9km S of Cabazon, CA
# 4          49 km SSW of Central, Alaska
# ...

# %%
df.to_csv('cleanLargerEqDataset', index = False)
